# %%
# huấn luyện 200 epochs mất 8h48
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image

# %%
import glob
malignant = glob.glob('/kaggle/input/multi-cancer/Multi Cancer/Breast Cancer/breast_malignant/*.*')
benign = glob.glob('/kaggle/input/multi-cancer/Multi Cancer/Breast Cancer/breast_benign/*.*')
#print(kidney_stone)
data = []
labels = []

for i in malignant:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    #print(image)
    image=np.array(image)
    data.append(image)
    labels.append(0)
    
for i in benign:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', target_size= (224,224))
    image=np.array(image)
    data.append(image)
    labels.append(1)

data = np.array(data)
labels = np.array(labels)
#print(data)
print(labels)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2,
                                                random_state=42)
# Out:
# [0 0 0 ... 1 1 1]

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 200
image_size = 224  # We'll resize input images to this size
patch_size = 16  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
X_train.shape
# Out:
# (8000, 224, 224, 3)

# %%
X_test.shape
# Out:
# (2000, 224, 224, 3)

# %%
y_train.shape
# Out:
# (8000,)

# %%
y_test.shape
# Out:
# (2000,)

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
#data_augmentation.layers[0].adapt(x_train)
data_augmentation.layers[0].adapt(X_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import cv2
from matplotlib import pyplot
from keras.preprocessing import image
datagen = image.ImageDataGenerator(rescale=1.0/255.0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
#image = x_train[np.random.choice(range(x_train.shape[0]))]
#print(image)
img=plt.imread("/kaggle/input/multi-cancer/Multi Cancer/Breast Cancer/breast_benign/breast_benign_0002.jpg")
#print(img)
plt.imshow(img.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([img]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 224 X 224
# Patch size: 16 X 16
# Patches per image: 196
# Elements per patch: 768

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, 
            key_dim=projection_dim, 
            dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)

# %%
input_shape=(224,224,3)
num_classes=2

# %%
model = create_vit_classifier()

# %%
model.compile(
    optimizer=optimizer,
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
       keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
       keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"), ],)

# %%
history = model.fit(
        x=X_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
    )
# Out:
# Epoch 1/200
# 29/29 [==============================] - 174s 5s/step - loss: 2.2983 - accuracy: 0.7256 - top-5-accuracy: 1.0000 - val_loss: 0.4770 - val_accuracy: 0.7812 - val_top-5-accuracy: 1.0000
# Epoch 2/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.4473 - accuracy: 0.8025 - top-5-accuracy: 1.0000 - val_loss: 0.3929 - val_accuracy: 0.8500 - val_top-5-accuracy: 1.0000
# Epoch 3/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.3726 - accuracy: 0.8326 - top-5-accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 0.8313 - val_top-5-accuracy: 1.0000
# Epoch 4/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.3619 - accuracy: 0.8363 - top-5-accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.8587 - val_top-5-accuracy: 1.0000
# Epoch 5/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.3199 - accuracy: 0.8567 - top-5-accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.8687 - val_top-5-accuracy: 1.0000
# Epoch 6/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.3013 - accuracy: 0.8672 - top-5-accuracy: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.8938 - val_top-5-accuracy: 1.0000
# Epoch 7/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.2669 - accuracy: 0.8894 - top-5-accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9112 - val_top-5-accuracy: 1.0000
# Epoch 8/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.2451 - accuracy: 0.8961 - top-5-accuracy: 1.0000 - val_loss: 0.2358 - val_accuracy: 0.9187 - val_top-5-accuracy: 1.0000
# Epoch 9/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.2053 - accuracy: 0.9117 - top-5-accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9388 - val_top-5-accuracy: 1.0000
# Epoch 10/200
# 29/29 [==============================] - 156s 5s/step - loss: 0.1745 - accuracy: 0.9289 - top-5-accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9362 - val_top-5-accuracy: 1.0000
# Epoch 11/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.1843 - accuracy: 0.9244 - top-5-accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9400 - val_top-5-accuracy: 1.0000
# Epoch 12/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.1464 - accuracy: 0.9407 - top-5-accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9438 - val_top-5-accuracy: 1.0000
# Epoch 13/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.1227 - accuracy: 0.9514 - top-5-accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9475 - val_top-5-accuracy: 1.0000
# Epoch 14/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.1235 - accuracy: 0.9482 - top-5-accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9488 - val_top-5-accuracy: 1.0000
# Epoch 15/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.1205 - accuracy: 0.9514 - top-5-accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9563 - val_top-5-accuracy: 1.0000
# Epoch 16/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0978 - accuracy: 0.9601 - top-5-accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9650 - val_top-5-accuracy: 1.0000
# Epoch 17/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.1060 - accuracy: 0.9569 - top-5-accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9650 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0845 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9650 - val_top-5-accuracy: 1.0000
# Epoch 19/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0731 - accuracy: 0.9688 - top-5-accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0736 - accuracy: 0.9688 - top-5-accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0712 - accuracy: 0.9712 - top-5-accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9700 - val_top-5-accuracy: 1.0000
# Epoch 22/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0683 - accuracy: 0.9728 - top-5-accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 0.9675 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0655 - accuracy: 0.9740 - top-5-accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 24/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0645 - accuracy: 0.9736 - top-5-accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9388 - val_top-5-accuracy: 1.0000
# Epoch 25/200
# 29/29 [==============================] - 156s 5s/step - loss: 0.1132 - accuracy: 0.9606 - top-5-accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 26/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0791 - accuracy: 0.9751 - top-5-accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 27/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0468 - accuracy: 0.9824 - top-5-accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9663 - val_top-5-accuracy: 1.0000
# Epoch 28/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0454 - accuracy: 0.9812 - top-5-accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0478 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9712 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0421 - accuracy: 0.9850 - top-5-accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0504 - accuracy: 0.9819 - top-5-accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9725 - val_top-5-accuracy: 1.0000
# Epoch 32/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0539 - accuracy: 0.9806 - top-5-accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 33/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0402 - accuracy: 0.9860 - top-5-accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9625 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0734 - accuracy: 0.9722 - top-5-accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 35/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0332 - accuracy: 0.9878 - top-5-accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 36/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0721 - accuracy: 0.9737 - top-5-accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 37/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0603 - accuracy: 0.9790 - top-5-accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 38/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0405 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0392 - accuracy: 0.9856 - top-5-accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9762 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0277 - accuracy: 0.9904 - top-5-accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 41/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0288 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9638 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0539 - accuracy: 0.9826 - top-5-accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0304 - accuracy: 0.9893 - top-5-accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 44/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0308 - accuracy: 0.9881 - top-5-accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 45/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0326 - accuracy: 0.9881 - top-5-accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 46/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0254 - accuracy: 0.9912 - top-5-accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 47/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0399 - accuracy: 0.9868 - top-5-accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 48/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0221 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 49/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0171 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 50/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0159 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 51/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0235 - accuracy: 0.9926 - top-5-accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 52/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0299 - accuracy: 0.9893 - top-5-accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 53/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0264 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 54/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0211 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 55/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0301 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 0.0545 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 56/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0201 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.2739 - val_accuracy: 0.9463 - val_top-5-accuracy: 1.0000
# Epoch 57/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0534 - accuracy: 0.9811 - top-5-accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 58/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0261 - accuracy: 0.9896 - top-5-accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 59/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0230 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 60/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0445 - accuracy: 0.9835 - top-5-accuracy: 1.0000 - val_loss: 0.0528 - val_accuracy: 0.9850 - val_top-5-accuracy: 1.0000
# Epoch 61/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0203 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 62/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0239 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9850 - val_top-5-accuracy: 1.0000
# Epoch 63/200
# 29/29 [==============================] - 157s 5s/step - loss: 0.0193 - accuracy: 0.9924 - top-5-accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9875 - val_top-5-accuracy: 1.0000
# Epoch 64/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0152 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9600 - val_top-5-accuracy: 1.0000
# Epoch 65/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0202 - accuracy: 0.9931 - top-5-accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 66/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0152 - accuracy: 0.9944 - top-5-accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 67/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0140 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9850 - val_top-5-accuracy: 1.0000
# Epoch 68/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0153 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 69/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0214 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 70/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0122 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 71/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0169 - accuracy: 0.9939 - top-5-accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9875 - val_top-5-accuracy: 1.0000
# Epoch 72/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0628 - accuracy: 0.9769 - top-5-accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 73/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0302 - accuracy: 0.9896 - top-5-accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 74/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0230 - accuracy: 0.9910 - top-5-accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 75/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0268 - accuracy: 0.9907 - top-5-accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 76/200
# 29/29 [==============================] - 162s 6s/step - loss: 0.0285 - accuracy: 0.9886 - top-5-accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9725 - val_top-5-accuracy: 1.0000
# Epoch 77/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0304 - accuracy: 0.9901 - top-5-accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 78/200
# 29/29 [==============================] - 160s 5s/step - loss: 0.0253 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9875 - val_top-5-accuracy: 1.0000
# Epoch 79/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0172 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9787 - val_top-5-accuracy: 1.0000
# Epoch 80/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0202 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 81/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0136 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9775 - val_top-5-accuracy: 1.0000
# Epoch 82/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0085 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9762 - val_top-5-accuracy: 1.0000
# Epoch 83/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0110 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 84/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0146 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9712 - val_top-5-accuracy: 1.0000
# Epoch 85/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0126 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9875 - val_top-5-accuracy: 1.0000
# Epoch 86/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0141 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9825 - val_top-5-accuracy: 1.0000
# Epoch 87/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0134 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9862 - val_top-5-accuracy: 1.0000
# Epoch 88/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0081 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 89/200
# 29/29 [==============================] - 161s 6s/step - loss: 0.0177 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9875 - val_top-5-accuracy: 1.0000
# Epoch 90/200
# 29/29 [==============================] - 162s 6s/step - loss: 0.0087 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9762 - val_top-5-accuracy: 1.0000
# Epoch 91/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0193 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9700 - val_top-5-accuracy: 1.0000
# Epoch 92/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0187 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9825 - val_top-5-accuracy: 1.0000
# Epoch 93/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0121 - accuracy: 0.9957 - top-5-accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9900 - val_top-5-accuracy: 1.0000
# Epoch 94/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.0097 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9800 - val_top-5-accuracy: 1.0000
# Epoch 95/200
# 29/29 [==============================] - 160s 6s/step - loss: 0.
uracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0258 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0520 - accuracy: 0.9822 - top-5-accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9750 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 29/29 [==============================] - 159s 5s/step - loss: 0.0224 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9850 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0271 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9825 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0099 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0038 - accuracy: 0.9990 - top-5-accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0053 - accuracy: 0.9982 - top-5-accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9837 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0079 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9887 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 29/29 [==============================] - 158s 5s/step - loss: 0.0098 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9812 - val_top-5-accuracy: 1.0000

# %%
results = model.evaluate(X_test, y_test)

print('Test loss: {:4f}'.format(results[0]))
print('Test accuracy: {:4f}'.format(results[1]))
# Out:
# 63/63 [==============================] - 2s 26ms/step - loss: 0.0825 - accuracy: 0.9865 - top-5-accuracy: 1.0000
# Test loss: 0.082469
# Test accuracy: 0.986500

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
plotOutput(history, 'Breast cancer', num_epochs)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
y_hat = model.predict(X_test)
y_pred = np.argmax(y_hat, axis=1)
#y_test_label =  np.argmax(y_test, axis=1)

y_test_label= y_test.reshape(-1, 1)
#print(y_test_label)
#print(y_pred)
# Tính accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test_label, y_pred)
print('Accuracy: %f' % accuracy)
# Tính precision tp / (tp + fp)
precision = precision_score(y_test_label, y_pred, average='macro')
print('Precision: %f' % precision)
# Tính recall: tp / (tp + fn)
recall = recall_score(y_test_label, y_pred, average='macro')
print('Recall: %f' % recall)
# Tính f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test_label, y_pred, average='macro')
print('F1 score: %f' % f1)
# Tính Area under ROC
auc = roc_auc_score(y_test, y_pred, multi_class='ovr')
print('ROC AUC: %f' % auc)
# Tính confusion matrix
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test_label, y_pred)
print('Confusion matrix:')
print(cnf_matrix)
#print('\nAccuracy:', np.diagonal(cnf_matrix).sum()/cnf_matrix.sum())

normalized_confusion_matrix = cnf_matrix/cnf_matrix.sum(axis = 1, keepdims = True)
print('\nConfusion matrix (with normalizatrion:)')
print(normalized_confusion_matrix)
# Out:
# 63/63 [==============================] - 3s 25ms/step
# Accuracy: 0.986500
# Precision: 0.986625
# Recall: 0.986636
# F1 score: 0.986500
# ROC AUC: 0.986636
# Confusion matrix:
# [[987  25]
#  [  2 986]]
#
# Confusion matrix (with normalizatrion:)
# [[0.97529644 0.02470356]
#  [0.00202429 0.99797571]]

# %%
import matplotlib.pyplot as plt
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1, keepdims = True)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Plot non-normalized confusion matrix
class_names = [0, 1]
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()

# %%
arr =['malignant','benign']
import cv2
img = cv2.imread('/kaggle/input/multi-cancer/Multi Cancer/Breast Cancer/breast_malignant/breast_malignant_0004.jpg')
import matplotlib.pyplot as plt
plt.imshow(img)
img = cv2.resize(img, (224,224))
i = np.array(img, dtype='float32')
arr_reshaped = i.reshape((-1,224,224,3))
output=model.predict(arr_reshaped)
result = arr[np.argmax(output)]
print(result)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# malignant
