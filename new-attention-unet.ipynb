# %%
path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/'

# %% [markdown]
# # Libraries

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tensorflow import keras
import os
import cv2
import timeit
import numpy as np 
import pandas as pd
from PIL import Image
from tensorflow import keras
import tensorflow as tf
from keras import Model
import matplotlib.pyplot as plt
from keras.metrics import MeanIoU
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential 
from tensorflow.keras.optimizers import SGD,Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img ,img_to_array
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report
from tensorflow.keras.layers import MaxPooling2D,BatchNormalization,Conv2D,Dense,Activation,Conv2DTranspose,Input
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D
from tensorflow.keras.layers import Conv2DTranspose, MaxPooling2D, concatenate, AveragePooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Flatten,Dropout,SpatialDropout2D,AveragePooling2D,GlobalAveragePooling2D,Concatenate

# %%
def num (image) :
    val = 0
    for i in range(len(image)) :
        if image[i] == '(' :
            while True :
                i += 1
                if image[i] == ')' :
                    break
                val = (val*10) + int(image[i])
            break
    return val

# %%
X_b, y_b = np.zeros((437, 128, 128, 1)), np.zeros((437, 128, 128, 1))
X_n, y_n = np.zeros((133, 128, 128, 1)), np.zeros((133, 128, 128, 1))
X_m, y_m= np.zeros((210, 128, 128, 1)), np.zeros((210, 128, 128, 1))

# %%
for i, tumor_type in enumerate(os.listdir(path)) :
    for image in os.listdir(path+tumor_type+'/') :
        p = os.path.join(path+tumor_type, image)
        img = cv2.imread(p,cv2.IMREAD_GRAYSCALE)           # read image as  grayscale
        
        if image[-5] == ')' :
            
            img = cv2.resize(img,(128,128))
            pil_img = Image.fromarray (img)
            
            if image[0] == 'b' :
                X_b[num(image)-1]+= img_to_array(pil_img)  # If image is real add it
            if image[0] == 'n' :                           # to X as benign , normal
                X_n[num(image)-1]+= img_to_array(pil_img)  # or malignant.
            if image[0] == 'm' :
                X_m[num(image)-1]+= img_to_array(pil_img)
        else :
            img = cv2.resize(img,(128,128))
            pil_img = Image.fromarray (img)
            
            if image[0] == 'b' :
                y_b[num(image)-1]+= img_to_array(pil_img)  # Similarly add the target
            if image[0] == 'n' :                           # mask to y.
                y_n[num(image)-1]+= img_to_array(pil_img)
            if image[0] == 'm' :
                y_m[num(image)-1]+= img_to_array(pil_img)

# %%
X = np.concatenate((X_b, X_n, X_m), axis = 0)
y = np.concatenate((y_b, y_n, y_m), axis = 0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (780, 128, 128, 1)
# (780, 128, 128, 1)

# %%
def convertToOneChannel(img):
    im=np.dot(img[...,:3], [0.2989, 0.5870, 0.1140])
    i=cv2.resize(im, (128, 128))
    return i

# %%
def convertToThreeChannel(img):
    b_np= np.array(img)
    g_np= np.array(img)
    r_np= np.array(img)
    final_img = np.dstack([b_np, g_np, r_np]).astype(np.uint8)
    return np.array(final_img)

# %%
img=convertToThreeChannel(X[10])
mask=convertToThreeChannel(y[10])
plt.figure
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(mask)
plt.title("masked image")
plt.show()

# %%
actual=[]
mask=[]
for i in X:
    horizontal_flip = cv2.flip(i, 1)
    vertical_horizontal_flip = cv2.flip(i, -1)
    imagerotate = cv2.rotate(i, cv2.ROTATE_180) 
    imagerotate1 = cv2.rotate(i, cv2.ROTATE_90_COUNTERCLOCKWISE)
    imagerotate2 = cv2.rotate(i, cv2.ROTATE_90_CLOCKWISE)
    actual.append(horizontal_flip)
    actual.append(vertical_horizontal_flip)
    actual.append(imagerotate)
    actual.append(imagerotate1)
    actual.append(imagerotate2)

for j in y:
    horizontal_flip_mask = cv2.flip(j, 1)
    vertical_horizontal_flip_mask = cv2.flip(j, -1)
    imagerotate_mask1 = cv2.rotate(j, cv2.ROTATE_90_COUNTERCLOCKWISE)
    imagerotate_mask = cv2.rotate(j, cv2.ROTATE_180)
    imagerotate_mask2 = cv2.rotate(j, cv2.ROTATE_90_CLOCKWISE)
    mask.append(horizontal_flip_mask)
    mask.append(vertical_horizontal_flip_mask)
    mask.append(imagerotate_mask)
    mask.append(imagerotate_mask1)
    mask.append(imagerotate_mask2)

# %%
mask=np.array(mask)
actual=np.array(actual)
print(actual.shape)
print(mask.shape)
# Out:
# (3900, 128, 128)
# (3900, 128, 128)

# %%
actual=actual/255
mask=mask/255
print(mask.max())
print(mask.min())
# Out:
# 2.0
# 0.0

# %%
mask[mask > 1.0] = 1.0

# %%
print(mask.max())
print(mask.min())
# Out:
# 1.0
# 0.0

# %%
mask=np.array(mask)
actual=np.array(actual)
print(actual.shape)
print(mask.shape)
# Out:
# (3900, 128, 128)
# (3900, 128, 128)

# %%
t1=np.full(2185,1) 
t2=np.full(665,0)
t3=np.full(1050,2)  
T=np.concatenate((t1, t2, t3), axis = 0)
T=np.array(T)

# %%
print(T.shape)
# Out:
# (3900,)

# %%
plt.figure
plt.subplot(1,2,1)
plt.imshow(actual[3000],interpolation='nearest',cmap='gray')
plt.title("original image")
plt.subplot(1,2,2)
plt.imshow(mask[3000],interpolation='nearest',cmap='gray')
plt.title("masked image")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(actual, mask, test_size = 0.15, random_state = 1)

# %%
actual1=[]
for i in actual:
    actual1.append(convertToThreeChannel(i) )
mask1=[]
for i in mask:
    mask1.append(convertToThreeChannel(i) )
actual1=np.array(actual1)
mask1=np.array(mask1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (3315, 128, 128)
# (585, 128, 128)

# %% [markdown]
# # Init model

# %%
import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model

def conv_block(x, num_filters):
    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = L.MaxPool2D((2, 2))(x)
    return x, p

def attention_gate(g, s, num_filters):
    Wg = L.Conv2D(num_filters, 1, padding="same")(g)
    Wg = L.BatchNormalization()(Wg)

    Ws = L.Conv2D(num_filters, 1, padding="same")(s)
    Ws = L.BatchNormalization()(Ws)

    out = L.Activation("relu")(Wg + Ws)
    out = L.Conv2D(num_filters, 1, padding="same")(out)
    out = L.Activation("sigmoid")(out)

    return out * s

def decoder_block(x, s, num_filters):
    x = L.UpSampling2D(interpolation="bilinear")(x)
    s = attention_gate(x, s, num_filters)
    x = L.Concatenate()([x, s])
    x = conv_block(x, num_filters)
    return x

def attention_unet(input_shape):
    """ Inputs """
    inputs = L.Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)

    b1 = conv_block(p3, 512)

    """ Decoder """
    d1 = decoder_block(b1, s3, 256)
    d2 = decoder_block(d1, s2, 128)
    d3 = decoder_block(d2, s1, 64)

    """ Outputs """
    outputs = L.Conv2D(1, 1, padding="same", activation="sigmoid")(d3)

    """ Model """
    model = Model(inputs, outputs, name="Attention-UNET")
    return model

# %%
input_shape = (128, 128, 1)
model = attention_unet(input_shape)
model.summary()
# Out:
# Model: "Attention-UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 64  640         ['input_4[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  36928       ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 64  256        ['conv2d_10[0][0]']
#  rmalization)                   )
#
#  activation_10 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['activation_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_15[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_15[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 512)  0          ['activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 256)  131328      ['up_sampling2d_3[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  tf.__operators__.add (TFOpLamb  (None, 32, 32, 256)  0          ['batch_normalization_16[0][0]',
#  da)                                                              'batch_normalization_17[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 256)  0           ['tf.__operators__.add[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 256)  65792       ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 256)  0           ['conv2d_19[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 32, 32, 256)  0           ['activation_18[0][0]',
#                                                                   'activation_14[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 768)  0           ['up_sampling2d_3[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 256)  1769728     ['concatenate_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_19[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 256)  0          ['activation_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 128)  32896       ['up_sampling2d_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_12[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 128)  512        ['conv2d_23[0][0]']
#  ormalization)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 64, 64, 128)  0          ['batch_normalization_20[0][0]',
#  mbda)                                                            'batch_normalization_21[0][0]']
#
#  activation_21 (Activation)     (None, 64, 64, 128)  0           ['tf.__operators__.add_1[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  16512       ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 64, 64, 128)  0           ['conv2d_24[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 64, 64, 128)  0          ['activation_22[0][0]',
#  )                                                                'activation_12[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 384)  0           ['up_sampling2d_4[0][0]',
#                                                                   'tf.math.multiply_1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  442496      ['concatenate_3[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_23[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_23[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 12  0          ['activation_24[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 64  8256        ['up_sampling2d_5[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 64  4160        ['activation_10[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 64  256        ['conv2d_27[0][0]']
#  ormalization)                  )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['conv2d_28[0][0]']
#  ormalization)                  )
#
#  tf.__operators__.add_2 (TFOpLa  (None, 128, 128, 64  0          ['batch_normalization_24[0][0]',
#  mbda)                          )                                 'batch_normalization_25[0][0]']
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['tf.__operators__.add_2[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 128, 128, 64  4160        ['activation_25[0][0]']
#                                 )
#
#  activation_26 (Activation)     (None, 128, 128, 64  0           ['conv2d_29[0][0]']
#                                 )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 128, 128, 64  0          ['activation_26[0][0]',
#  )                              )                                 'activation_10[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 19  0           ['up_sampling2d_5[0][0]',
#                                 2)                                'tf.math.multiply_2[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 64  110656      ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 64  256        ['conv2d_30[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 64  36928       ['activation_27[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 1)  65          ['activation_28[0][0]']
#
# ==================================================================================================
# Total params: 8,142,017
# Trainable params: 8,134,593
# Non-trainable params: 7,424
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, './model_plot.png', show_shapes = True)

# %%
from keras.metrics import MeanIoU

# %%
model.compile(loss = 'mean_squared_error', optimizer = keras.optimizers.Adam(learning_rate = 0.00001),metrics=['acc'])

# %%
from keras.callbacks import ModelCheckpoint

# %%
checkp = ModelCheckpoint('./attention_unet_model.h5', monitor = 'accuracy', save_best_only = True, verbose = 1)

# %% [markdown]
# # Trainning model

# %%
history = model.fit(X_train, y_train, epochs = 200, batch_size = 8, validation_data = (X_test, y_test), callbacks = [checkp])
# Out:
# Epoch 1/200
# 415/415 [==============================] - 59s 85ms/step - loss: 0.1190 - acc: 0.8810 - val_loss: 0.0806 - val_acc: 0.9287
# Epoch 2/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0668 - acc: 0.9353 - val_loss: 0.0670 - val_acc: 0.9377
# Epoch 3/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0568 - acc: 0.9436 - val_loss: 0.0499 - val_acc: 0.9538
# Epoch 4/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0511 - acc: 0.9484 - val_loss: 0.0448 - val_acc: 0.9563
# Epoch 5/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0470 - acc: 0.9515 - val_loss: 0.0409 - val_acc: 0.9584
# Epoch 6/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0434 - acc: 0.9546 - val_loss: 0.0385 - val_acc: 0.9603
# Epoch 7/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0402 - acc: 0.9576 - val_loss: 0.0418 - val_acc: 0.9564
# Epoch 8/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0378 - acc: 0.9594 - val_loss: 0.0337 - val_acc: 0.9632
# Epoch 9/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0348 - acc: 0.9624 - val_loss: 0.0354 - val_acc: 0.9612
# Epoch 10/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0331 - acc: 0.9636 - val_loss: 0.0336 - val_acc: 0.9629
# Epoch 11/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0302 - acc: 0.9668 - val_loss: 0.0318 - val_acc: 0.9635
# Epoch 12/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0280 - acc: 0.9688 - val_loss: 0.0483 - val_acc: 0.9420
# Epoch 13/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0264 - acc: 0.9703 - val_loss: 0.0318 - val_acc: 0.9632
# Epoch 14/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0245 - acc: 0.9722 - val_loss: 0.0314 - val_acc: 0.9632
# Epoch 15/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0227 - acc: 0.9739 - val_loss: 0.0279 - val_acc: 0.9667
# Epoch 16/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0215 - acc: 0.9750 - val_loss: 0.0292 - val_acc: 0.9649
# Epoch 17/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0200 - acc: 0.9765 - val_loss: 0.0255 - val_acc: 0.9695
# Epoch 18/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0188 - acc: 0.9776 - val_loss: 0.0324 - val_acc: 0.9604
# Epoch 19/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0175 - acc: 0.9790 - val_loss: 0.0389 - val_acc: 0.9513
# Epoch 20/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0168 - acc: 0.9795 - val_loss: 0.0274 - val_acc: 0.9660
# Epoch 21/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0158 - acc: 0.9806 - val_loss: 0.0233 - val_acc: 0.9713
# Epoch 22/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0146 - acc: 0.9818 - val_loss: 0.0301 - val_acc: 0.9623
# Epoch 23/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0145 - acc: 0.9818 - val_loss: 0.0244 - val_acc: 0.9695
# Epoch 24/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0136 - acc: 0.9826 - val_loss: 0.0252 - val_acc: 0.9685
# Epoch 25/200
# 415/415 [==============================] - 33s 81ms/step - loss: 0.0126 - acc: 0.9838 - val_loss: 0.0227 - val_acc: 0.9716
# Epoch 26/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.
200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0013 - acc: 0.9964 - val_loss: 0.0203 - val_acc: 0.9757
# Epoch 168/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0021 - acc: 0.9955 - val_loss: 0.0214 - val_acc: 0.9744
# Epoch 169/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0016 - acc: 0.9961 - val_loss: 0.0202 - val_acc: 0.9759
# Epoch 170/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0012 - acc: 0.9965 - val_loss: 0.0387 - val_acc: 0.9524
# Epoch 171/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0014 - acc: 0.9963 - val_loss: 0.0199 - val_acc: 0.9761
# Epoch 172/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0200 - val_acc: 0.9761
# Epoch 173/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0209 - val_acc: 0.9748
# Epoch 174/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0198 - val_acc: 0.9764
# Epoch 175/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0016 - acc: 0.9961 - val_loss: 0.0234 - val_acc: 0.9725
# Epoch 176/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0015 - acc: 0.9961 - val_loss: 0.0201 - val_acc: 0.9760
# Epoch 177/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0013 - acc: 0.9965 - val_loss: 0.0199 - val_acc: 0.9763
# Epoch 178/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0012 - acc: 0.9966 - val_loss: 0.0202 - val_acc: 0.9761
# Epoch 179/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0199 - val_acc: 0.9764
# Epoch 180/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0200 - val_acc: 0.9761
# Epoch 181/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0200 - val_acc: 0.9762
# Epoch 182/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0012 - acc: 0.9966 - val_loss: 0.0201 - val_acc: 0.9761
# Epoch 183/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0013 - acc: 0.9964 - val_loss: 0.0205 - val_acc: 0.9758
# Epoch 184/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0013 - acc: 0.9965 - val_loss: 0.0197 - val_acc: 0.9766
# Epoch 185/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0204 - val_acc: 0.9756
# Epoch 186/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9966 - val_loss: 0.0200 - val_acc: 0.9763
# Epoch 187/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0207 - val_acc: 0.9751
# Epoch 188/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0200 - val_acc: 0.9762
# Epoch 189/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9966 - val_loss: 0.0207 - val_acc: 0.9759
# Epoch 190/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0022 - acc: 0.9954 - val_loss: 0.0197 - val_acc: 0.9763
# Epoch 191/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0196 - val_acc: 0.9766
# Epoch 192/200
# 415/415 [==============================] - 34s 81ms/step - loss: 9.3932e-04 - acc: 0.9969 - val_loss: 0.0197 - val_acc: 0.9766
# Epoch 193/200
# 415/415 [==============================] - 33s 79ms/step - loss: 9.7300e-04 - acc: 0.9968 - val_loss: 0.0202 - val_acc: 0.9759
# Epoch 194/200
# 415/415 [==============================] - 34s 81ms/step - loss: 9.8067e-04 - acc: 0.9968 - val_loss: 0.0200 - val_acc: 0.9764
# Epoch 195/200
# 415/415 [==============================] - 34s 81ms/step - loss: 9.7538e-04 - acc: 0.9968 - val_loss: 0.0199 - val_acc: 0.9765
# Epoch 196/200
# 415/415 [==============================] - 34s 81ms/step - loss: 9.7482e-04 - acc: 0.9968 - val_loss: 0.0198 - val_acc: 0.9765
# Epoch 197/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0011 - acc: 0.9967 - val_loss: 0.0197 - val_acc: 0.9767
# Epoch 198/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0010 - acc: 0.9967 - val_loss: 0.0197 - val_acc: 0.9767
# Epoch 199/200
# 415/415 [==============================] - 34s 81ms/step - loss: 0.0010 - acc: 0.9968 - val_loss: 0.0197 - val_acc: 0.9767
# Epoch 200/200
# 415/415 [==============================] - 33s 79ms/step - loss: 0.0018 - acc: 0.9958 - val_loss: 0.0210 - val_acc: 0.9751

# %%
def plotOutput(history, className, epochs):
    k = ''
    if 'accuracy' in history.history :
        k = 'accuracy'    

    if 'acc' in history.history :
        k = 'acc'
    
    acc = history.history[k]
    val_acc = history.history['val_'+k]

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %% [markdown]
# # Model Metrics

# %%
plotOutput(history, 'Breast cancer', 200)

# %%
#6679s
score = model.evaluate(X_test, y_test, verbose = 1) 
print('Test loss:', score[0]) 
print('Test accuracy:', score[1]*100)
# Out:
# 19/19 [==============================] - 5s 137ms/step - loss: 0.0210 - acc: 0.9751
# Test loss: 0.02100793831050396
# Test accuracy: 97.50975370407104

# %%
model.save("./attention-unet.h5")

# %%
def imgpredicting(img):
    x=[]
    x.append(img)
    x=np.array(x)
    output=model.predict(x)
    #print(output)
    output=np.array(output)
    output.shape
    array = np.reshape(output[0], (128, 128))
    print(array.shape)
    return array

# %%
plt.figure
plt.subplot(1,3,1)
plt.imshow(actual[3000],interpolation='nearest',cmap='gray')
plt.title("original image")
plt.subplot(1,3,2)
plt.imshow(mask[3000],interpolation='nearest',cmap='gray')
plt.title(" actual masked ")
plt.subplot(1,3,3)
plt.imshow(imgpredicting(actual[3000]),interpolation='nearest',cmap='gray')
plt.title(" predicted masked ")
plt.show()
# Out:
# 1/1 [==============================] - 0s 431ms/step
# (128, 128)
