# %%
# huấn luyện 200 epochs mất 4h51
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.2)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %% [markdown]
# # Func init Model

# %%
def initiateModel(noOfClasses):
    modelInput = tf.keras.applications.ResNet50V2(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'ResNet50V2.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=200, batchSize = 32):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg1=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg1)
    loss = evl[0]*100
    msg2=f'Loss on the Test Set = {loss:5.2f} %'
    print(msg2)
    
def saveModel(model, className):
    model.save(className + " - ResNet50V2.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'../input/multi-cancer/Multi Cancer'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 200
lr = 0.00001

for i in classPaths:
    className = i
    print(className)
# Out:
# Cervical Cancer
# Lung and Colon Cancer
# Oral Cancer
# ALL
# Kidney Cancer
# Breast Cancer
# Lymphoma
# Brain Cancer

# %%
className = 'Breast Cancer '
cpath = os.path.join(mpath, 'Breast Cancer')

# %%
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 8000 images belonging to 2 classes.
#
# For Val :  Found 2000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['breast_benign', 'breast_malignant']
# Image Shape :  (32, 256, 256, 3)

# %%
curModel = initiateModel(noOfClasses)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 3s 0us/step

# %%
modelSummary(curModel)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['post_relu[0][0]']
#
#  dense (Dense)                  (None, 2)            200706      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,765,506
# Trainable params: 23,720,066
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)

# %% [markdown]
# # Train model

# %%
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=32)
# Out:
# Epoch 1/200
# 250/250 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8468
# Epoch 1: val_loss improved from inf to 0.18804, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 241s 835ms/step - loss: 0.3963 - accuracy: 0.8468 - val_loss: 0.1880 - val_accuracy: 0.9390 - lr: 1.0000e-05
# Epoch 2/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9789
# Epoch 2: val_loss improved from 0.18804 to 0.12771, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 90s 360ms/step - loss: 0.0801 - accuracy: 0.9789 - val_loss: 0.1277 - val_accuracy: 0.9555 - lr: 1.0000e-05
# Epoch 3/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9950
# Epoch 3: val_loss improved from 0.12771 to 0.10877, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 90s 361ms/step - loss: 0.0301 - accuracy: 0.9950 - val_loss: 0.1088 - val_accuracy: 0.9620 - lr: 1.0000e-05
# Epoch 4/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9977
# Epoch 4: val_loss improved from 0.10877 to 0.09637, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 92s 367ms/step - loss: 0.0172 - accuracy: 0.9977 - val_loss: 0.0964 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 5/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9989
# Epoch 5: val_loss improved from 0.09637 to 0.08795, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 90s 359ms/step - loss: 0.0106 - accuracy: 0.9989 - val_loss: 0.0880 - val_accuracy: 0.9680 - lr: 1.0000e-05
# Epoch 6/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9995
# Epoch 6: val_loss improved from 0.08795 to 0.08366, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 89s 354ms/step - loss: 0.0073 - accuracy: 0.9995 - val_loss: 0.0837 - val_accuracy: 0.9690 - lr: 1.0000e-05
# Epoch 7/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9995
# Epoch 7: val_loss improved from 0.08366 to 0.07902, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 90s 358ms/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.0790 - val_accuracy: 0.9720 - lr: 1.0000e-05
# Epoch 8/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9995
# Epoch 8: val_loss did not improve from 0.07902
# 250/250 [==============================] - 88s 350ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0874 - val_accuracy: 0.9705 - lr: 1.0000e-05
# Epoch 9/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 9: val_loss improved from 0.07902 to 0.07524, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 94s 376ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9710 - lr: 1.0000e-05
# Epoch 10/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9999
# Epoch 10: val_loss improved from 0.07524 to 0.07017, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 89s 354ms/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0702 - val_accuracy: 0.9745 - lr: 1.0000e-05
# Epoch 11/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 11: val_loss improved from 0.07017 to 0.06577, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9775 - lr: 1.0000e-05
# Epoch 12/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 12: val_loss did not improve from 0.06577
# 250/250 [==============================] - 88s 350ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0758 - val_accuracy: 0.9765 - lr: 1.0000e-05
# Epoch 13/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 13: val_loss improved from 0.06577 to 0.06061, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 349ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0606 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 14/200
# 250/250 [==============================] - ETA: 0s - loss: 8.7955e-04 - accuracy: 0.9999
# Epoch 14: val_loss did not improve from 0.06061
# 250/250 [==============================] - 85s 341ms/step - loss: 8.7955e-04 - accuracy: 0.9999 - val_loss: 0.0619 - val_accuracy: 0.9780 - lr: 1.0000e-05
# Epoch 15/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 15: val_loss did not improve from 0.06061
# 250/250 [==============================] - 85s 341ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0641 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 16/200
# 250/250 [==============================] - ETA: 0s - loss: 5.1503e-04 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.06061
# 250/250 [==============================] - 86s 343ms/step - loss: 5.1503e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 17/200
# 250/250 [==============================] - ETA: 0s - loss: 3.5056e-04 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.06061
# 250/250 [==============================] - 85s 341ms/step - loss: 3.5056e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 18/200
# 250/250 [==============================] - ETA: 0s - loss: 5.5356e-04 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.06061
# 250/250 [==============================] - 85s 341ms/step - loss: 5.5356e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9780 - lr: 1.0000e-05
# Epoch 19/200
# 250/250 [==============================] - ETA: 0s - loss: 4.1443e-04 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.06061
# 250/250 [==============================] - 86s 343ms/step - loss: 4.1443e-04 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9770 - lr: 1.0000e-05
# Epoch 20/200
# 250/250 [==============================] - ETA: 0s - loss: 2.7217e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.06061
# 250/250 [==============================] - 85s 340ms/step - loss: 2.7217e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9800 - lr: 1.0000e-05
# Epoch 21/200
# 250/250 [==============================] - ETA: 0s - loss: 3.8454e-04 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.06061 to 0.05634, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 86s 343ms/step - loss: 3.8454e-04 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9805 - lr: 1.0000e-05
# Epoch 22/200
# 250/250 [==============================] - ETA: 0s - loss: 3.6686e-04 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.05634 to 0.05628, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 3.6686e-04 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9820 - lr: 1.0000e-05
# Epoch 23/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4470e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.05628
# 250/250 [==============================] - 85s 339ms/step - loss: 2.4470e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 24/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6563e-04 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.05628
# 250/250 [==============================] - 85s 338ms/step - loss: 1.6563e-04 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9815 - lr: 1.0000e-05
# Epoch 25/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3419e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.05628 to 0.05439, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 350ms/step - loss: 1.3419e-04 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9830 - lr: 1.0000e-05
# Epoch 26/200
# 250/250 [==============================] - ETA: 0s - loss: 3.1042e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.05439
# 250/250 [==============================] - 86s 344ms/step - loss: 3.1042e-04 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9815 - lr: 1.0000e-05
# Epoch 27/200
# 250/250 [==============================] - ETA: 0s - loss: 4.2229e-04 - accuracy: 0.9999
# Epoch 27: val_loss did not improve from 0.05439
# 250/250 [==============================] - 90s 361ms/step - loss: 4.2229e-04 - accuracy: 0.9999 - val_loss: 0.0645 - val_accuracy: 0.9790 - lr: 1.0000e-05
# Epoch 28/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 28: val_loss improved from 0.05439 to 0.04819, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0482 - val_accuracy: 0.9835 - lr: 1.0000e-05
# Epoch 29/200
# 250/250 [==============================] - ETA: 0s - loss: 2.5850e-04 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.04819 to 0.04815, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 348ms/step - loss: 2.5850e-04 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9845 - lr: 1.0000e-05
# Epoch 30/200
# 250/250 [==============================] - ETA: 0s - loss: 2.8588e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.04815
# 250/250 [==============================] - 86s 343ms/step - loss: 2.8588e-04 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9850 - lr: 1.0000e-05
# Epoch 31/200
# 250/250 [==============================] - ETA: 0s - loss: 1.4862e-04 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.04815
# 250/250 [==============================] - 86s 344ms/step - loss: 1.4862e-04 - accuracy: 1.0000 - val_loss: 0.0505 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 32/200
# 250/250 [==============================] - ETA: 0s - loss: 9.6079e-05 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.04815
# 250/250 [==============================] - 86s 344ms/step - loss: 9.6079e-05 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 33/200
# 250/250 [==============================] - ETA: 0s - loss: 8.2183e-05 - accuracy: 1.0000
# Epoch 33: val_loss did not improve from 0.04815
# 250/250 [==============================] - 87s 347ms/step - loss: 8.2183e-05 - accuracy: 1.0000 - val_loss: 0.0513 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 34/200
# 250/250 [==============================] - ETA: 0s - loss: 9.3992e-05 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.04815 to 0.04572, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 9.3992e-05 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 35/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6483e-04 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.04572
# 250/250 [==============================] - 85s 340ms/step - loss: 1.6483e-04 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9850 - lr: 1.0000e-05
# Epoch 36/200
# 250/250 [==============================] - ETA: 0s - loss: 6.5958e-04 - accuracy: 0.9998
# Epoch 36: val_loss did not improve from 0.04572
# 250/250 [==============================] - 86s 345ms/step - loss: 6.5958e-04 - accuracy: 0.9998 - val_loss: 0.0603 - val_accuracy: 0.9820 - lr: 1.0000e-05
# Epoch 37/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 37: val_loss did not improve from 0.04572
# 250/250 [==============================] - 85s 341ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0584 - val_accuracy: 0.9810 - lr: 1.0000e-05
# Epoch 38/200
# 250/250 [==============================] - ETA: 0s - loss: 3.5123e-04 - accuracy: 0.9999
# Epoch 38: val_loss did not improve from 0.04572
# 250/250 [==============================] - 85s 339ms/step - loss: 3.5123e-04 - accuracy: 0.9999 - val_loss: 0.0563 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 39/200
# 250/250 [==============================] - ETA: 0s - loss: 1.9485e-04 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.04572
# 250/250 [==============================] - 86s 343ms/step - loss: 1.9485e-04 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 40/200
# 250/250 [==============================] - ETA: 0s - loss: 6.8445e-05 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.04572
# 250/250 [==============================] - 85s 341ms/step - loss: 6.8445e-05 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9845 - lr: 1.0000e-05
# Epoch 41/200
# 250/250 [==============================] - ETA: 0s - loss: 4.5760e-05 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.04572
# 250/250 [==============================] - 86s 342ms/step - loss: 4.5760e-05 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9865 - lr: 1.0000e-05
# Epoch 42/200
# 250/250 [==============================] - ETA: 0s - loss: 6.3166e-05 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.04572 to 0.04409, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 86s 343ms/step - loss: 6.3166e-05 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9850 - lr: 1.0000e-05
# Epoch 43/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 43: val_loss improved from 0.04409 to 0.03613, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0361 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 44/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0439e-04 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 346ms/step - loss: 1.0439e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 45/200
# 250/250 [==============================] - ETA: 0s - loss: 4.6467e-05 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 4.6467e-05 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 46/200
# 250/250 [==============================] - ETA: 0s - loss: 3.9699e-05 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 3.9699e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 47/200
# 250/250 [==============================] - ETA: 0s - loss: 3.9883e-05 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 3.9883e-05 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 48/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3972e-04 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 1.3972e-04 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 49/200
# 250/250 [==============================] - ETA: 0s - loss: 1.2424e-04 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 1.2424e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 50/200
# 250/250 [==============================] - ETA: 0s - loss: 4.1172e-04 - accuracy: 0.9999
# Epoch 50: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 4.1172e-04 - accuracy: 0.9999 - val_loss: 0.0511 - val_accuracy: 0.9845 - lr: 1.0000e-05
# Epoch 51/200
# 250/250 [==============================] - ETA: 0s - loss: 6.9370e-05 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 6.9370e-05 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 52/200
# 250/250 [==============================] - ETA: 0s - loss: 3.8745e-05 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.03613
# 250/250 [==============================] - 90s 361ms/step - loss: 3.8745e-05 - accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 0.9865 - lr: 1.0000e-05
# Epoch 53/200
# 250/250 [==============================] - ETA: 0s - loss: 1.9271e-05 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 1.9271e-05 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 54/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4645e-05 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 2.4645e-05 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 55/200
# 250/250 [==============================] - ETA: 0s - loss: 2.7061e-05 - accuracy: 1.0000
# Epoch 55: val_loss did not improve from 0.03613
# 250/250 [==============================] - 84s 338ms/step - loss: 2.7061e-05 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 56/200
# 250/250 [==============================] - ETA: 0s - loss: 8.4195e-06 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 338ms/step - loss: 8.4195e-06 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 57/200
# 250/250 [==============================] - ETA: 0s - loss: 3.1123e-04 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 3.1123e-04 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 58/200
# 250/250 [==============================] - ETA: 0s - loss: 1.7116e-04 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.03613
# 250/250 [==============================] - 91s 364ms/step - loss: 1.7116e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 59/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0800e-04 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.03613
# 250/250 [==============================] - 89s 355ms/step - loss: 1.0800e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 60/200
# 250/250 [==============================] - ETA: 0s - loss: 5.2766e-04 - accuracy: 0.9998
# Epoch 60: val_loss did not improve from 0.03613
# 250/250 [==============================] - 88s 351ms/step - loss: 5.2766e-04 - accuracy: 0.9998 - val_loss: 0.0429 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 61/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4825e-04 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.4825e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 62/200
# 250/250 [==============================] - ETA: 0s - loss: 2.1201e-05 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 2.1201e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 63/200
# 250/250 [==============================] - ETA: 0s - loss: 2.8848e-05 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 2.8848e-05 - accuracy: 1.0000 - val_loss: 0.0505 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 64/200
# 250/250 [==============================] - ETA: 0s - loss: 7.0211e-05 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 7.0211e-05 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 65/200
# 250/250 [==============================] - ETA: 0s - loss: 5.5879e-05 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 5.5879e-05 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 66/200
# 250/250 [==============================] - ETA: 0s - loss: 7.5235e-06 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 7.5235e-06 - accuracy: 1.0000 - val_loss: 0.0458 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 67/200
# 250/250 [==============================] - ETA: 0s - loss: 6.3303e-05 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 6.3303e-05 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 68/200
# 250/250 [==============================] - ETA: 0s - loss: 1.7313e-05 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 1.7313e-05 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 69/200
# 250/250 [==============================] - ETA: 0s - loss: 2.7342e-05 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.7342e-05 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 70/200
# 250/250 [==============================] - ETA: 0s - loss: 2.1028e-05 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 2.1028e-05 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 71/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 71: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0657 - val_accuracy: 0.9815 - lr: 1.0000e-05
# Epoch 72/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4489e-04 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 2.4489e-04 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 73/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6690e-04 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 1.6690e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 74/200
# 250/250 [==============================] - ETA: 0s - loss: 1.9802e-05 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 1.9802e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 75/200
# 250/250 [==============================] - ETA: 0s - loss: 1.7431e-05 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.03613
# 250/250 [==============================] - 89s 357ms/step - loss: 1.7431e-05 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 76/200
# 250/250 [==============================] - ETA: 0s - loss: 9.7796e-06 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 9.7796e-06 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 77/200
# 250/250 [==============================] - ETA: 0s - loss: 9.3759e-04 - accuracy: 0.9998
# Epoch 77: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 9.3759e-04 - accuracy: 0.9998 - val_loss: 0.0606 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 78/200
# 250/250 [==============================] - ETA: 0s - loss: 6.3634e-05 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 6.3634e-05 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 79/200
# 250/250 [==============================] - ETA: 0s - loss: 2.9023e-05 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 338ms/step - loss: 2.9023e-05 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 80/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4361e-05 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.4361e-05 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 81/200
# 250/250 [==============================] - ETA: 0s - loss: 7.0461e-06 - accuracy: 1.0000
# Epoch 81: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 7.0461e-06 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 82/200
# 250/250 [==============================] - ETA: 0s - loss: 6.9201e-06 - accuracy: 1.0000
# Epoch 82: val_loss did not improve from 0.03613
# 250/250 [==============================] - 84s 336ms/step - loss: 6.9201e-06 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 83/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0351e-05 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 1.0351e-05 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 84/200
# 250/250 [==============================] - ETA: 0s - loss: 9.3683e-06 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 9.3683e-06 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 85/200
# 250/250 [==============================] - ETA: 0s - loss: 2.9114e-06 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.9114e-06 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 86/200
# 250/250 [==============================] - ETA: 0s - loss: 3.5273e-06 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 341ms/step - loss: 3.5273e-06 - accuracy: 1.0000 - val_loss: 0.0490 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 87/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1476e-05 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 1.1476e-05 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 88/200
# 250/250 [==============================] - ETA: 0s - loss: 2.5958e-06 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 2.5958e-06 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 89/200
# 250/250 [==============================] - ETA: 0s - loss: 3.1014e-06 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 3.1014e-06 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9865 - lr: 1.0000e-05
# Epoch 90/200
# 250/250 [==============================] - ETA: 0s - loss: 7.6951e-06 - accuracy: 1.0000
# Epoch 90: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 7.6951e-06 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 91/200
# 250/250 [==============================] - ETA: 0s - loss: 2.7392e-06 - accuracy: 1.0000
# Epoch 91: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.7392e-06 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 92/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3275e-06 - accuracy: 1.0000
# Epoch 92: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 1.3275e-06 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 0.9880 - lr: 1.0000e-05
# Epoch 93/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1725e-06 - accuracy: 1.0000
# Epoch 93: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 1.1725e-06 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9875 - lr: 1.0000e-05
# Epoch 94/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6809e-05 - accuracy: 1.0000
# Epoch 94: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 1.6809e-05 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 95/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9995
# Epoch 95: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0580 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 96/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0066e-04 - accuracy: 0.9999
# Epoch 96: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 348ms/step - loss: 2.0066e-04 - accuracy: 0.9999 - val_loss: 0.0406 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 97/200
# 250/250 [==============================] - ETA: 0s - loss: 9.3147e-05 - accuracy: 1.0000
# Epoch 97: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 9.3147e-05 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 98/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0775e-05 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 2.0775e-05 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 99/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1384e-05 - accuracy: 1.0000
# Epoch 99: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 346ms/step - loss: 1.1384e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 100/200
# 250/250 [==============================] - ETA: 0s - loss: 9.7533e-06 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 346ms/step - loss: 9.7533e-06 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 101/200
# 250/250 [==============================] - ETA: 0s - loss: 5.3164e-06 - accuracy: 1.0000
# Epoch 101: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 5.3164e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 102/200
# 250/250 [==============================] - ETA: 0s - loss: 7.2383e-06 - accuracy: 1.0000
# Epoch 102: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 7.2383e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 103/200
# 250/250 [==============================] - ETA: 0s - loss: 7.9425e-06 - accuracy: 1.0000
# Epoch 103: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 7.9425e-06 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 104/200
# 250/250 [==============================] - ETA: 0s - loss: 2.7525e-06 - accuracy: 1.0000
# Epoch 104: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 349ms/step - loss: 2.7525e-06 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9910 - lr: 1.0000e-05
# Epoch 105/200
# 250/250 [==============================] - ETA: 0s - loss: 7.7900e-04 - accuracy: 0.9999
# Epoch 105: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 7.7900e-04 - accuracy: 0.9999 - val_loss: 0.0444 - val_accuracy: 0.9910 - lr: 1.0000e-05
# Epoch 106/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 106: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0523 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 107/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6585e-05 - accuracy: 1.0000
# Epoch 107: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 1.6585e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 108/200
# 250/250 [==============================] - ETA: 0s - loss: 1.2492e-05 - accuracy: 1.0000
# Epoch 108: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 1.2492e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 109/200
# 250/250 [==============================] - ETA: 0s - loss: 4.6244e-05 - accuracy: 1.0000
# Epoch 109: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 4.6244e-05 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 110/200
# 250/250 [==============================] - ETA: 0s - loss: 8.8782e-06 - accuracy: 1.0000
# Epoch 110: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 8.8782e-06 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 111/200
# 250/250 [==============================] - ETA: 0s - loss: 3.9535e-06 - accuracy: 1.0000
# Epoch 111: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 3.9535e-06 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 112/200
# 250/250 [==============================] - ETA: 0s - loss: 8.0563e-06 - accuracy: 1.0000
# Epoch 112: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 8.0563e-06 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 113/200
# 250/250 [==============================] - ETA: 0s - loss: 8.8820e-06 - accuracy: 1.0000
# Epoch 113: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 8.8820e-06 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 114/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0732e-05 - accuracy: 1.0000
# Epoch 114: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 1.0732e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 115/200
# 250/250 [==============================] - ETA: 0s - loss: 4.2592e-06 - accuracy: 1.0000
# Epoch 115: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 4.2592e-06 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 116/200
# 250/250 [==============================] - ETA: 0s - loss: 4.6066e-06 - accuracy: 1.0000
# Epoch 116: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 4.6066e-06 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 117/200
# 250/250 [==============================] - ETA: 0s - loss: 3.5248e-06 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 3.5248e-06 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 118/200
# 250/250 [==============================] - ETA: 0s - loss: 4.0693e-06 - accuracy: 1.0000
# Epoch 118: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 4.0693e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 119/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1888e-06 - accuracy: 1.0000
# Epoch 119: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 1.1888e-06 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 120/200
# 250/250 [==============================] - ETA: 0s - loss: 3.1695e-06 - accuracy: 1.0000
# Epoch 120: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 3.1695e-06 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 121/200
# 250/250 [==============================] - ETA: 0s - loss: 1.9167e-06 - accuracy: 1.0000
# Epoch 121: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 1.9167e-06 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 122/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1906e-06 - accuracy: 1.0000
# Epoch 122: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 1.1906e-06 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 123/200
# 250/250 [==============================] - ETA: 0s - loss: 2.2316e-06 - accuracy: 1.0000
# Epoch 123: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.2316e-06 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 124/200
# 250/250 [==============================] - ETA: 0s - loss: 1.6482e-06 - accuracy: 1.0000
# Epoch 124: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 1.6482e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 125/200
# 250/250 [==============================] - ETA: 0s - loss: 6.9795e-07 - accuracy: 1.0000
# Epoch 125: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 6.9795e-07 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 126/200
# 250/250 [==============================] - ETA: 0s - loss: 3.9686e-07 - accuracy: 1.0000
# Epoch 126: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 349ms/step - loss: 3.9686e-07 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 127/200
# 250/250 [==============================] - ETA: 0s - loss: 8.0783e-07 - accuracy: 1.0000
# Epoch 127: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 8.0783e-07 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 128/200
# 250/250 [==============================] - ETA: 0s - loss: 2.2483e-06 - accuracy: 1.0000
# Epoch 128: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 2.2483e-06 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 129/200
# 250/250 [==============================] - ETA: 0s - loss: 6.3034e-07 - accuracy: 1.0000
# Epoch 129: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 6.3034e-07 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 130/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0182e-06 - accuracy: 1.0000
# Epoch 130: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 1.0182e-06 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 131/200
# 250/250 [==============================] - ETA: 0s - loss: 6.7559e-07 - accuracy: 1.0000
# Epoch 131: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 6.7559e-07 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 132/200
# 250/250 [==============================] - ETA: 0s - loss: 4.6300e-07 - accuracy: 1.0000
# Epoch 132: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 4.6300e-07 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 133/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1703e-06 - accuracy: 1.0000
# Epoch 133: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 338ms/step - loss: 1.1703e-06 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 134/200
# 250/250 [==============================] - ETA: 0s - loss: 3.3668e-07 - accuracy: 1.0000
# Epoch 134: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 346ms/step - loss: 3.3668e-07 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 135/200
# 250/250 [==============================] - ETA: 0s - loss: 2.9960e-07 - accuracy: 1.0000
# Epoch 135: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 342ms/step - loss: 2.9960e-07 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 136/200
# 250/250 [==============================] - ETA: 0s - loss: 3.4733e-07 - accuracy: 1.0000
# Epoch 136: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 3.4733e-07 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 137/200
# 250/250 [==============================] - ETA: 0s - loss: 9.5970e-08 - accuracy: 1.0000
# Epoch 137: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 9.5970e-08 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 138/200
# 250/250 [==============================] - ETA: 0s - loss: 2.4426e-07 - accuracy: 1.0000
# Epoch 138: val_loss did not improve from 0.03613
# 250/250 [==============================] - 84s 337ms/step - loss: 2.4426e-07 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 139/200
# 250/250 [==============================] - ETA: 0s - loss: 2.3623e-07 - accuracy: 1.0000
# Epoch 139: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 338ms/step - loss: 2.3623e-07 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 140/200
# 250/250 [==============================] - ETA: 0s - loss: 1.2638e-07 - accuracy: 1.0000
# Epoch 140: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 1.2638e-07 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 141/200
# 250/250 [==============================] - ETA: 0s - loss: 1.9285e-07 - accuracy: 1.0000
# Epoch 141: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 345ms/step - loss: 1.9285e-07 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 142/200
# 250/250 [==============================] - ETA: 0s - loss: 4.7959e-08 - accuracy: 1.0000
# Epoch 142: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 346ms/step - loss: 4.7959e-08 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 143/200
# 250/250 [==============================] - ETA: 0s - loss: 9.3246e-08 - accuracy: 1.0000
# Epoch 143: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 9.3246e-08 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 144/200
# 250/250 [==============================] - ETA: 0s - loss: 4.5080e-08 - accuracy: 1.0000
# Epoch 144: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 340ms/step - loss: 4.5080e-08 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 145/200
# 250/250 [==============================] - ETA: 0s - loss: 5.6212e-08 - accuracy: 1.0000
# Epoch 145: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 5.6212e-08 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 146/200
# 250/250 [==============================] - ETA: 0s - loss: 5.7503e-08 - accuracy: 1.0000
# Epoch 146: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 5.7503e-08 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 147/200
# 250/250 [==============================] - ETA: 0s - loss: 9.6351e-08 - accuracy: 1.0000
# Epoch 147: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 9.6351e-08 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 148/200
# 250/250 [==============================] - ETA: 0s - loss: 8.1582e-08 - accuracy: 1.0000
# Epoch 148: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 343ms/step - loss: 8.1582e-08 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 149/200
# 250/250 [==============================] - ETA: 0s - loss: 3.7253e-08 - accuracy: 1.0000
# Epoch 149: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 339ms/step - loss: 3.7253e-08 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 150/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0175e-07 - accuracy: 1.0000
# Epoch 150: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 2.0175e-07 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 151/200
# 250/250 [==============================] - ETA: 0s - loss: 1.4357e-07 - accuracy: 1.0000
# Epoch 151: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 342ms/step - loss: 1.4357e-07 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 152/200
# 250/250 [==============================] - ETA: 0s - loss: 7.0404e-08 - accuracy: 1.0000
# Epoch 152: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 338ms/step - loss: 7.0404e-08 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 153/200
# 250/250 [==============================] - ETA: 0s - loss: 9.4882e-08 - accuracy: 1.0000
# Epoch 153: val_loss did not improve from 0.03613
# 250/250 [==============================] - 87s 347ms/step - loss: 9.4882e-08 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 154/200
# 250/250 [==============================] - ETA: 0s - loss: 3.7656e-07 - accuracy: 1.0000
# Epoch 154: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 3.7656e-07 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 155/200
# 250/250 [==============================] - ETA: 0s - loss: 6.3990e-07 - accuracy: 1.0000
# Epoch 155: val_loss did not improve from 0.03613
# 250/250 [==============================] - 86s 344ms/step - loss: 6.3990e-07 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9910 - lr: 1.0000e-05
# Epoch 156/200
# 250/250 [==============================] - ETA: 0s - loss: 8.7424e-07 - accuracy: 1.0000
# Epoch 156: val_loss did not improve from 0.03613
# 250/250 [==============================] - 85s 341ms/step - loss: 8.7424e-07 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 157/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0653e-04 - accuracy: 0.9999
# Epoch 157: val_loss improved from 0.03613 to 0.02884, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 349ms/step - loss: 1.0653e-04 - accuracy: 0.9999 - val_loss: 0.0288 - val_accuracy: 0.9940 - lr: 1.0000e-05
# Epoch 158/200
# 250/250 [==============================] - ETA: 0s - loss: 7.6764e-04 - accuracy: 0.9996
# Epoch 158: val_loss did not improve from 0.02884
# 250/250 [==============================] - 87s 346ms/step - loss: 7.6764e-04 - accuracy: 0.9996 - val_loss: 0.0881 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 159/200
# 250/250 [==============================] - ETA: 0s - loss: 3.7360e-04 - accuracy: 0.9999
# Epoch 159: val_loss did not improve from 0.02884
# 250/250 [==============================] - 85s 342ms/step - loss: 3.7360e-04 - accuracy: 0.9999 - val_loss: 0.0305 - val_accuracy: 0.9945 - lr: 1.0000e-05
# Epoch 160/200
# 250/250 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9995
# Epoch 160: val_loss did not improve from 0.02884
# 250/250 [==============================] - 85s 341ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0345 - val_accuracy: 0.9930 - lr: 1.0000e-05
# Epoch 161/200
# 250/250 [==============================] - ETA: 0s - loss: 4.5326e-04 - accuracy: 0.9998
# Epoch 161: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 343ms/step - loss: 4.5326e-04 - accuracy: 0.9998 - val_loss: 0.0398 - val_accuracy: 0.9910 - lr: 1.0000e-05
# Epoch 162/200
# 250/250 [==============================] - ETA: 0s - loss: 2.3667e-04 - accuracy: 0.9999
# Epoch 162: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 345ms/step - loss: 2.3667e-04 - accuracy: 0.9999 - val_loss: 0.0469 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 163/200
# 250/250 [==============================] - ETA: 0s - loss: 5.9797e-06 - accuracy: 1.0000
# Epoch 163: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 342ms/step - loss: 5.9797e-06 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 164/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3472e-04 - accuracy: 1.0000
# Epoch 164: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 345ms/step - loss: 1.3472e-04 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 165/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0360e-06 - accuracy: 1.0000
# Epoch 165: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 344ms/step - loss: 2.0360e-06 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 166/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1277e-05 - accuracy: 1.0000
# Epoch 166: val_loss did not improve from 0.02884
# 250/250 [==============================] - 85s 341ms/step - loss: 1.1277e-05 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 167/200
# 250/250 [==============================] - ETA: 0s - loss: 4.4187e-06 - accuracy: 1.0000
# Epoch 167: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 344ms/step - loss: 4.4187e-06 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 168/200
# 250/250 [==============================] - ETA: 0s - loss: 2.9311e-06 - accuracy: 1.0000
# Epoch 168: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 345ms/step - loss: 2.9311e-06 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 169/200
# 250/250 [==============================] - ETA: 0s - loss: 6.4973e-06 - accuracy: 1.0000
# Epoch 169: val_loss did not improve from 0.02884
# 250/250 [==============================] - 86s 343ms/step - loss: 6.4973e-06 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 170/200
# 250/250 [==============================] - ETA: 0s - loss: 3.9234e-06 - accuracy: 1.0000
# Epoch 170: val_loss did not improve from 0.02884
# 250/250 [==============================] - 87s 349ms/step - loss: 3.9234e-06 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 171/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0717e-06 - accuracy: 1.0000
# Epoch 171: val_loss did not improve from 0.02884
# 250/250 [==============================] - 91s 364ms/step - loss: 2.0717e-06 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9925 - lr: 1.0000e-05
# Epoch 172/200
# 250/250 [==============================] - ETA: 0s - loss: 7.1314e-06 - accuracy: 1.0000
# Epoch 172: val_loss did not improve from 0.02884
# 250/250 [==============================] - 87s 347ms/step - loss: 7.1314e-06 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9930 - lr: 1.0000e-05
# Epoch 173/200
# 250/250 [==============================] - ETA: 0s - loss: 5.2684e-05 - accuracy: 1.0000
# Epoch 173: val_loss did not improve from 0.02884
# 250/250 [==============================] - 90s 362ms/step - loss: 5.2684e-05 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9915 - lr: 1.0000e-05
# Epoch 174/200
# 250/250 [==============================] - ETA: 0s - loss: 3.0664e-04 - accuracy: 0.9999
# Epoch 174: val_loss improved from 0.02884 to 0.02845, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 88s 351ms/step - loss: 3.0664e-04 - accuracy: 0.9999 - val_loss: 0.0285 - val_accuracy: 0.9930 - lr: 1.0000e-05
# Epoch 175/200
# 250/250 [==============================] - ETA: 0s - loss: 4.9633e-04 - accuracy: 0.9999
# Epoch 175: val_loss did not improve from 0.02845
# 250/250 [==============================] - 86s 344ms/step - loss: 4.9633e-04 - accuracy: 0.9999 - val_loss: 0.0331 - val_accuracy: 0.9930 - lr: 1.0000e-05
# Epoch 176/200
# 250/250 [==============================] - ETA: 0s - loss: 2.6158e-05 - accuracy: 1.0000
# Epoch 176: val_loss did not improve from 0.02845
# 250/250 [==============================] - 86s 343ms/step - loss: 2.6158e-05 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9930 - lr: 1.0000e-05
# Epoch 177/200
# 250/250 [==============================] - ETA: 0s - loss: 1.8125e-05 - accuracy: 1.0000
# Epoch 177: val_loss improved from 0.02845 to 0.02766, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 350ms/step - loss: 1.8125e-05 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 178/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3270e-05 - accuracy: 1.0000
# Epoch 178: val_loss did not improve from 0.02766
# 250/250 [==============================] - 85s 341ms/step - loss: 1.3270e-05 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 179/200
# 250/250 [==============================] - ETA: 0s - loss: 2.3967e-06 - accuracy: 1.0000
# Epoch 179: val_loss did not improve from 0.02766
# 250/250 [==============================] - 86s 344ms/step - loss: 2.3967e-06 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 180/200
# 250/250 [==============================] - ETA: 0s - loss: 1.5510e-06 - accuracy: 1.0000
# Epoch 180: val_loss did not improve from 0.02766
# 250/250 [==============================] - 86s 343ms/step - loss: 1.5510e-06 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9915 - lr: 1.0000e-05
# Epoch 181/200
# 250/250 [==============================] - ETA: 0s - loss: 1.1613e-06 - accuracy: 1.0000
# Epoch 181: val_loss did not improve from 0.02766
# 250/250 [==============================] - 85s 340ms/step - loss: 1.1613e-06 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 182/200
# 250/250 [==============================] - ETA: 0s - loss: 8.5429e-07 - accuracy: 1.0000
# Epoch 182: val_loss did not improve from 0.02766
# 250/250 [==============================] - 86s 345ms/step - loss: 8.5429e-07 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 183/200
# 250/250 [==============================] - ETA: 0s - loss: 1.2932e-06 - accuracy: 1.0000
# Epoch 183: val_loss did not improve from 0.02766
# 250/250 [==============================] - 87s 348ms/step - loss: 1.2932e-06 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9915 - lr: 1.0000e-05
# Epoch 184/200
# 250/250 [==============================] - ETA: 0s - loss: 5.7344e-05 - accuracy: 1.0000
# Epoch 184: val_loss did not improve from 0.02766
# 250/250 [==============================] - 86s 342ms/step - loss: 5.7344e-05 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 185/200
# 250/250 [==============================] - ETA: 0s - loss: 6.7157e-06 - accuracy: 1.0000
# Epoch 185: val_loss improved from 0.02766 to 0.02610, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 346ms/step - loss: 6.7157e-06 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 186/200
# 250/250 [==============================] - ETA: 0s - loss: 2.0393e-06 - accuracy: 1.0000
# Epoch 186: val_loss improved from 0.02610 to 0.02549, saving model to Breast Cancer ResNet50V2.h5
# 250/250 [==============================] - 87s 347ms/step - loss: 2.0393e-06 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9920 - lr: 1.0000e-05
# Epoch 187/200
# 250/250 [==============================] - ETA: 0s - loss: 1.0619e-05 - accuracy: 1.0000
# Epoch 187: val_loss did not improve from 0.02549
# 250/250 [==============================] - 85s 341ms/step - loss: 1.0619e-05 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 188/200
# 250/250 [==============================] - ETA: 0s - loss: 1.3762e-04 - accuracy: 1.0000
# Epoch 188: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 343ms/step - loss: 1.3762e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9935 - lr: 1.0000e-05
# Epoch 189/200
# 250/250 [==============================] - ETA: 0s - loss: 3.1001e-05 - accuracy: 1.0000
# Epoch 189: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 344ms/step - loss: 3.1001e-05 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 190/200
# 250/250 [==============================] - ETA: 0s - loss: 7.5761e-06 - accuracy: 1.0000
# Epoch 190: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 345ms/step - loss: 7.5761e-06 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 191/200
# 250/250 [==============================] - ETA: 0s - loss: 1.5713e-06 - accuracy: 1.0000
# Epoch 191: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 345ms/step - loss: 1.5713e-06 - accuracy: 1.0000 - val_loss: 0.0520 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 192/200
# 250/250 [==============================] - ETA: 0s - loss: 6.8840e-07 - accuracy: 1.0000
# Epoch 192: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 348ms/step - loss: 6.8840e-07 - accuracy: 1.0000 - val_loss: 0.0532 - val_accuracy: 0.9905 - lr: 1.0000e-05
# Epoch 193/200
# 250/250 [==============================] - ETA: 0s - loss: 1.4107e-06 - accuracy: 1.0000
# Epoch 193: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 345ms/step - loss: 1.4107e-06 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 194/200
# 250/250 [==============================] - ETA: 0s - loss: 7.3690e-04 - accuracy: 0.9999
# Epoch 194: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 343ms/step - loss: 7.3690e-04 - accuracy: 0.9999 - val_loss: 0.1216 - val_accuracy: 0.9810 - lr: 1.0000e-05
# Epoch 195/200
# 250/250 [==============================] - ETA: 0s - loss: 5.9919e-05 - accuracy: 1.0000
# Epoch 195: val_loss did not improve from 0.02549
# 250/250 [==============================] - 86s 343ms/step - loss: 5.9919e-05 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9860 - lr: 1.0000e-05
# Epoch 196/200
# 250/250 [==============================] - ETA: 0s - loss: 5.0321e-05 - accuracy: 1.0000
# Epoch 196: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 348ms/step - loss: 5.0321e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 197/200
# 250/250 [==============================] - ETA: 0s - loss: 9.7749e-06 - accuracy: 1.0000
# Epoch 197: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 347ms/step - loss: 9.7749e-06 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9890 - lr: 1.0000e-05
# Epoch 198/200
# 250/250 [==============================] - ETA: 0s - loss: 6.8761e-06 - accuracy: 1.0000
# Epoch 198: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 347ms/step - loss: 6.8761e-06 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9895 - lr: 1.0000e-05
# Epoch 199/200
# 250/250 [==============================] - ETA: 0s - loss: 2.1024e-05 - accuracy: 1.0000
# Epoch 199: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 346ms/step - loss: 2.1024e-05 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9900 - lr: 1.0000e-05
# Epoch 200/200
# 250/250 [==============================] - ETA: 0s - loss: 3.8886e-06 - accuracy: 1.0000
# Epoch 200: val_loss did not improve from 0.02549
# 250/250 [==============================] - 87s 348ms/step - loss: 3.8886e-06 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9905 - lr: 1.0000e-05

# %% [markdown]
# # Model Metrics

# %%
plotOutput(curHistory, className, gEpochs)

# %%
evalModel(curModel)
# Out:
# 63/63 [==============================] - 17s 274ms/step - loss: 0.0551 - accuracy: 0.9905
# Accuracy on the Test Set = 99.05 %
# Loss on the Test Set =  5.51 %

# %%
saveModel(curModel, className)
# Out:
# Model Saved!

# %%
callPlot(curModel, className, class_names)
# Out:
# True :  [0 0 0 ... 1 1 1]
# 63/63 [==============================] - 17s 262ms/step
# Predicted :  [0 0 0 ... 1 1 1]

# %% [markdown]
# # Test Model

# %%
arr =['benign','malignant']
import cv2
img = cv2.imread('/kaggle/input/multi-cancer/Multi Cancer/Breast Cancer/breast_malignant/breast_malignant_0001.jpg')
import matplotlib.pyplot as plt
plt.imshow(img)
img = cv2.resize(img, (224,224))
i = np.array(img, dtype='float32')
arr_reshaped = i.reshape((-1,224,224,3))
output=curModel.predict(arr_reshaped)
result = arr[np.argmax(output)]
print(result)
# Out:
# 1/1 [==============================] - 1s 959ms/step
# malignant
